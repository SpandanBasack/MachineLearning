# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 468          469         0       3          Scanlan, Mr. James    male   NaN
# 274          275         1       3  Healy, Miss. Hanora "Nora"  female   NaN
# 401          402         0       3             Adams, Mr. John    male  26.0
# 344          345         0       2     Fox, Mr. Stanley Hubert    male  36.0
# 786          787         1       3   Sjoblom, Miss. Anna Sofia  female  18.0
#
#      SibSp  Parch   Ticket     Fare Cabin Embarked
# 468      0      0    36209   7.7250   NaN        Q
# 274      0      0   370375   7.7500   NaN        Q
# 401      0      0   341826   8.0500   NaN        S
# 344      0      0   229236  13.0000   NaN        S
# 786      0      0  3101265   7.4958   NaN        S

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.bar([0,1],[df[df['Survived']==0]['Survived'].count(), df[df['Survived']==1]['Survived'].count()], tick_label = [0,1], color=['blue', 'orange'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots()
column = 'Embarked'
unique_categories = df[df[column].notna()][column].unique()
ax.bar(unique_categories, df[column].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.pie(df['Sex'].value_counts(), labels = ['male', 'female'], autopct='%1.1f%%')
# df['Sex'].value_counts()
# Out:
# ([<matplotlib.patches.Wedge at 0x1a2d1a09850>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'female')],
#  [Text(-0.2683338620074884, 0.5366534622082915, '64.8%'),
#   Text(0.26833391225261044, -0.53665343708506, '35.2%')])

# %%
import numpy as np
from scipy.stats import gaussian_kde
def normalize(data):
    return (data - data.min()) / (data.max() - data.min())
n_data = normalize(df["Age"].dropna())
fig, ax = plt.subplots()
ax.hist(n_data, bins=10, alpha=0.5)
kde = gaussian_kde(n_data)
x_range = np.linspace(min(n_data), max(n_data), 500)
kde_values = kde(x_range)
ax.plot(x_range, kde_values*71.5746421268, color='red')

# %%
fig, ax = plt.subplots()
ax.boxplot(df["Age"].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a2d35a3b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a2d3be42d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a2d3bd6590>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a2d3be54d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a2d3be5d50>],
#  'means': []}

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893
