# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 772          773         0       2               Mack, Mrs. (Mary)  female
# 134          135         0       2  Sobey, Mr. Samuel James Hayden    male
# 695          696         0       2      Chapman, Mr. Charles Henry    male
# 308          309         0       2             Abelson, Mr. Samuel    male
# 540          541         1       1         Crosby, Miss. Harriet R  female
#
#       Age  SibSp  Parch       Ticket  Fare Cabin Embarked
# 772  57.0      0      0  S.O./P.P. 3  10.5   E77        S
# 134  25.0      0      0   C.A. 29178  13.0   NaN        S
# 695  52.0      0      0       248731  13.5   NaN        S
# 308  30.0      1      0    P/PP 3381  24.0   NaN        C
# 540  36.0      0      2    WE/P 5735  71.0   B22        S

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.bar([0,1],[df[df['Survived']==0]['Survived'].count(), df[df['Survived']==1]['Survived'].count()], tick_label = [0,1], color=['blue', 'orange'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots()
column = 'Embarked'
unique_categories = df[df[column].notna()][column].unique()
ax.bar(unique_categories, df[column].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.pie(df['Sex'].value_counts(), labels = ['male', 'female'], autopct='%1.1f%%')
# df['Sex'].value_counts()
# Out:
# ([<matplotlib.patches.Wedge at 0x19f32408ad0>,
#   <matplotlib.patches.Wedge at 0x19f32480210>],
#  [Text(-0.4919454136803954, 0.9838646807152012, 'male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'female')],
#  [Text(-0.2683338620074884, 0.5366534622082915, '64.8%'),
#   Text(0.26833391225261044, -0.53665343708506, '35.2%')])
