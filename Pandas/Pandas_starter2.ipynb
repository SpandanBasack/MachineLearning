# %%
import pandas as pd

# %%
data = pd.read_json('cuisine.json')
data
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=f9f39b3500cc69eb3ee1f4292ba79b62')

# %%
type(response.json()['results'])
# Out:
# list

# %%
pd.DataFrame(response.json()['results'])[['id', 'overview', 'popularity', 'title', 'release_date', 'vote_average', 'vote_count']]
# Out:
#         id                                           overview  popularity  \
# 0      278  Imprisoned in the 1940s for the double murder ...     134.064
# 1      238  Spanning the years 1945 to 1955, a chronicle o...     124.789
# 2      240  In the continuing saga of the Corleone crime f...     153.549
# 3      424  The true story of how businessman Oskar Schind...      72.259
# 4      389  The defense and the prosecution have rested an...      77.730
# 5    19404  Raj is a rich, carefree, happy-go-lucky second...      44.609
# 6      129  A young girl, Chihiro, becomes trapped in a st...      99.361
# 7      155  Batman raises the stakes in his war on crime. ...      97.806
# 8   496243  All unemployed, Ki-taek's family takes peculia...      80.302
# 9      497  A supernatural tale set on death row in a Sout...      95.318
# 10  372058  High schoolers Mitsuha and Taki are complete s...      92.168
# 11     680  A burger-loving hit man, his philosophical par...     383.569
# ...

# %%
df = pd.DataFrame()

# %%
headers = {
    "accept": "application/json",
    "Authorization": "f9f39b3500cc69eb3ee1f4292ba79b62"
}
# print(requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=f9f39b3500cc69eb3ee1f4292ba79b62&language=en-US&page={i}', headers = headers).json())
for i in range(1, 472):
    res = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=f9f39b3500cc69eb3ee1f4292ba79b62&language=en-US&page={i}', headers = headers)
    tf = pd.DataFrame(res.json()['results'])[['id', 'overview', 'popularity', 'title', 'release_date', 'vote_average', 'vote_count']]
    df = pd.concat([df,tf], ignore_index=True)
# type(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9417 entries, 0 to 9416
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9417 non-null   int64
#  1   overview      9417 non-null   object
#  2   popularity    9417 non-null   float64
#  3   title         9417 non-null   object
#  4   release_date  9417 non-null   object
#  5   vote_average  9417 non-null   float64
#  6   vote_count    9417 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 515.1+ KB

# %%
df
# Out:
#          id                                           overview  popularity  \
# 0       278  Imprisoned in the 1940s for the double murder ...     134.064
# 1       238  Spanning the years 1945 to 1955, a chronicle o...     124.789
# 2       240  In the continuing saga of the Corleone crime f...     153.549
# 3       424  The true story of how businessman Oskar Schind...      72.259
# 4       389  The defense and the prosecution have rested an...      77.730
# ...     ...                                                ...         ...
# 9412  12142  Edward Carnby is a private investigator specia...      13.790
# 9413  13805  The filmmaking team behind the hits "Scary Mov...      29.693
# 9414  11059  Set on an island off the coast, a techno rave ...      13.429
# 9415  14164  On his 18th birthday, Goku receives a mystical...      21.465
# 9416  40016  A platoon of eagles and vultures attacks the r...       9.499
#
# ...

# %%
df.to_csv('movies.csv')
